# %%
import pandas as pd
import warnings

# %%
data = pd.read_csv(r"Z:\Predictive-Modelling-for-Housing-Prices\train.csv")
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
data.shape
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      6.321918  2007.815753  180921.195890
# std       2.703626     1.328095   79442.502883
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  129975.000000
# 50%       6.000000  2008.000000  163000.000000
# 75%       8.000000  2009.000000  214000.000000
# max      12.000000  2010.000000  755000.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
data.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
# Street              2
# Alley               2
# LotShape            4
# LandContour         4
# Utilities           2
# LotConfig           5
# LandSlope           3
# Neighborhood       25
# Condition1          9
# Condition2          8
# BldgType            5
# HouseStyle          8
# OverallQual        10
# OverallCond         9
# YearBuilt         112
# YearRemodAdd       61
# RoofStyle           6
# RoofMatl            8
# Exterior1st        15
# Exterior2nd        16
# MasVnrType          3
# MasVnrArea        327
# ExterQual           4
# ExterCond           5
# Foundation          6
# BsmtQual            4
# BsmtCond            4
# BsmtExposure        4
# BsmtFinType1        6
# BsmtFinSF1        637
# BsmtFinType2        6
# BsmtFinSF2        144
# BsmtUnfSF         780
# TotalBsmtSF       721
# Heating             6
# HeatingQC           5
# CentralAir          2
# Electrical          5
# 1stFlrSF          753
# 2ndFlrSF          417
# LowQualFinSF       24
# GrLivArea         861
# BsmtFullBath        4
# BsmtHalfBath        3
# FullBath            4
# HalfBath            3
# BedroomAbvGr        8
# KitchenAbvGr        4
# KitchenQual         4
# TotRmsAbvGrd       12
# Functional          7
# Fireplaces          4
# FireplaceQu         5
# GarageType          6
# GarageYrBlt        97
# GarageFinish        3
# GarageCars          5
# GarageArea        441
# GarageQual          5
# GarageCond          5
# PavedDrive          3
# WoodDeckSF        274
# OpenPorchSF       202
# EnclosedPorch     120
# 3SsnPorch          20
# ScreenPorch        76
# PoolArea            8
# PoolQC              3
# Fence               4
# MiscFeature         4
# MiscVal            21
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# dtype: int64

# %%
TargetVariable = 'SalePrice'
CategoricalVariables = []
ContinousVariables = []
RedundantVariables = []
PredictorVariables = []

for column in data.columns:
    if data[column].isnull().sum() > 200:
        RedundantVariables.append(column)
    else:
        if data[column].name != 'SalePrice' and data[column].name != "Id":
            if data[column].dtype == "object":
                CategoricalVariables.append(column)
            elif data[column].dtype == "float64":
                ContinousVariables.append(column)
            elif data[column].dtype == 'int64':
                if data[column].nunique() < 10:
                    CategoricalVariables.append(column)
                else:
                    ContinousVariables.append(column)

# %%
import seaborn as sns
sns.displot(data[TargetVariables], kde= True)
data[TargetVariables].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# for variables in CategoricalVariables:
#     data[variables].fillna(data[variables].mode(), inplace = True)
# for variables in ContinousVariables:
#     data[variables].fillna(data[variables].mean(), inplace = True)
    
# for variable in RedundantVariables:
#     data.drop([variable], axis=1, inplace=True)
    
testdata = pd.read_csv(r"Z:\Predictive-Modelling-for-Housing-Prices\test.csv")
# for variable in CategoricalVariables:
#     testdata[variable].fillna(testdata[variable].mode()[0], inplace=True)
# for variables in ContinousVariables:
#     testdata[variables].fillna(testdata[variables].mean(), inplace = True)

for variable in CategoricalVariables:
    data[variable].fillna(data[variable].mode()[0], inplace=True)

for variable in ContinousVariables:
    data[variable].fillna(data[variable].mean(), inplace=True)

for variable in RedundantVariables:
    data.drop([variable], axis=1, inplace=True)
    
for variable in CategoricalVariables:
    testdata[variable].fillna(testdata[variable].mode()[0], inplace=True)

for variable in ContinousVariables:
    testdata[variable].fillna(testdata[variable].mean(), inplace=True)

for variable in RedundantVariables:
    testdata.drop([variable], axis=1, inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinalEncoder = OrdinalEncoder()
data[CategoricalVariables] = ordinalEncoder.fit_transform(data[CategoricalVariables])
testdata[CategoricalVariables] = ordinalEncoder.fit_transform(testdata[CategoricalVariables])

# %%
data.sample(10)
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 1257  1258          30       3.0     4060     1.0       3.0          3.0
# 683    684          20       3.0    11248     1.0       0.0          3.0
# 1012  1013          70       3.0    10592     1.0       3.0          3.0
# 1018  1019          80       3.0    10784     1.0       0.0          3.0
# 1355  1356          80       3.0    10192     1.0       0.0          3.0
# 809    810          75       4.0     8100     1.0       3.0          3.0
# 446    447          20       3.0    16492     1.0       0.0          3.0
# 927    928          60       3.0     9900     1.0       3.0          3.0
# 975    976         160       1.0     2651     1.0       3.0          3.0
# 1354  1355          60       3.0    10316     1.0       0.0          3.0
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 1257        0.0        0.0        0.0           7.0         1.0         2.0
# 683         0.0        0.0        0.0           5.0         2.0         2.0
# 1012        0.0        4.0        0.0           6.0         2.0         2.0
# 1018        0.0        2.0        0.0           8.0         2.0         2.0
# 1355        0.0        4.0        0.0          14.0         2.0         2.0
# 809         0.0        0.0        0.0          17.0         2.0         2.0
# 446         0.0        0.0        0.0          12.0         3.0         2.0
# 927         0.0        4.0        0.0          14.0         1.0         2.0
# 975         0.0        2.0        0.0          21.0         2.0         2.0
# 1354        0.0        4.0        0.0           5.0         2.0         2.0
#
#       BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 1257       0.0         2.0            5          7.0       1922          1950
# 683        0.0         2.0            9          4.0       2002          2002
# 1012       0.0         5.0            6          6.0       1923          1996
# 1018       0.0         7.0            7          4.0       1991          1992
# 1355       0.0         7.0            7          5.0       1968          1992
# 809        0.0         4.0            5          4.0       1898          1965
# 446        0.0         2.0            6          5.0       1966          2002
# 927        0.0         5.0            7          4.0       1968          1968
# 975        3.0         5.0            7          4.0       2000          2000
# 1354       0.0         5.0            7          4.0       2000          2000
#
#       RoofStyle  RoofMatl  Exterior1st  Exterior2nd  MasVnrArea  ExterQual  \
# 1257        1.0       1.0         13.0         14.0         0.0        3.0
# 683         3.0       1.0         12.0         13.0       215.0        2.0
# 1012        3.0       1.0         13.0         14.0         0.0        3.0
# 1018        1.0       1.0          6.0          6.0        76.0        2.0
# 1355        1.0       1.0          8.0          8.0       143.0        3.0
# 809         3.0       1.0          0.0          0.0         0.0        3.0
# 446         1.0       1.0          3.0         10.0         0.0        2.0
# 927         1.0       1.0          8.0          8.0       342.0        3.0
# 975         1.0       1.0          8.0          8.0         0.0        2.0
# 1354        1.0       1.0         12.0         13.0         0.0        2.0
#
#       ExterCond  Foundation  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  \
# 1257        4.0         2.0       1.0       3.0           3.0           5.0
# 683         4.0         2.0       2.0       3.0           0.0           2.0
# 1012        2.0         2.0       3.0       0.0           3.0           5.0
# 1018        4.0         2.0       2.0       3.0           3.0           5.0
# 1355        4.0         1.0       3.0       3.0           3.0           5.0
# 809         4.0         2.0       3.0       3.0           3.0           5.0
# 446         4.0         1.0       3.0       3.0           3.0           0.0
# 927         4.0         1.0       3.0       3.0           3.0           1.0
# 975         4.0         2.0       2.0       3.0           3.0           2.0
# 1354        4.0         2.0       2.0       3.0           3.0           2.0
#
#       BsmtFinSF1  BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  \
# 1257           0           5.0           0        864          864      1.0
# 683         1059           5.0           0        567         1626      1.0
# 1012           0           5.0           0        602          602      1.0
# 1018           0           5.0           0        384          384      1.0
# 1355           0           5.0           0        570          570      1.0
# 809            0           5.0           0        849          849      1.0
# 446          247           4.0         713        557         1517      1.0
# 927          552           5.0           0        280          832      1.0
# 975          641           5.0           0         32          673      1.0
# 1354         735           5.0           0        257          992      1.0
#
#       HeatingQC  CentralAir  Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 1257        0.0         1.0         4.0       864         0             0
# 683         0.0         1.0         4.0      1668         0             0
# 1012        4.0         1.0         4.0       900       602             0
# 1018        2.0         1.0         4.0       802       670             0
# 1355        2.0         1.0         4.0      1222       698             0
# 809         4.0         0.0         0.0      1075      1063             0
# 446         0.0         1.0         4.0      1888         0             0
# 927         2.0         1.0         4.0      1098       880             0
# 975         0.0         1.0         4.0       673       709             0
# 1354        0.0         1.0         4.0       992       873             0
#
#       GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 1257        864           0.0           0.0       1.0       0.0           2.0
# 683        1668           1.0           0.0       2.0       0.0           3.0
# 1012       1502           0.0           0.0       1.0       1.0           3.0
# 1018       1472           0.0           0.0       2.0       1.0           3.0
# 1355       1920           0.0           0.0       3.0       0.0           4.0
# 809        2138           0.0           0.0       2.0       0.0           2.0
# 446        1888           0.0           0.0       2.0       1.0           2.0
# 927        1978           0.0           0.0       2.0       1.0           4.0
# 975        1382           1.0           0.0       2.0       1.0           3.0
# 1354       1865           1.0           0.0       2.0       1.0           3.0
#
#       KitchenAbvGr  KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  \
# 1257           1.0          3.0             4         6.0         0.0
# 683            1.0          2.0             7         6.0         1.0
# 1012           1.0          2.0             7         6.0         2.0
# 1018           1.0          2.0             7         6.0         1.0
# 1355           1.0          2.0             8         6.0         1.0
# 809            3.0          3.0            11         6.0         0.0
# 446            1.0          2.0             6         4.0         1.0
# 927            1.0          3.0             9         6.0         1.0
# 975            1.0          2.0             6         6.0         0.0
# 1354           1.0          2.0             7         6.0         1.0
#
#       GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 1257         1.0  1978.506164           2.0         0.0           0
# 683          1.0  2002.000000           0.0         3.0         702
# 1012         5.0  1923.000000           2.0         1.0         180
# 1018         1.0  1991.000000           1.0         2.0         402
# 1355         1.0  1968.000000           1.0         2.0         487
# 809          5.0  1910.000000           2.0         2.0         360
# 446          1.0  1966.000000           0.0         2.0         578
# 927          1.0  1968.000000           1.0         2.0         486
# 975          5.0  2000.000000           2.0         2.0         490
# 1354         1.0  2000.000000           1.0         3.0         839
#
#       GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  \
# 1257         4.0         4.0         2.0           0           96
# 683          4.0         4.0         2.0         257           45
# 1012         4.0         4.0         2.0          96            0
# 1018         4.0         4.0         2.0         164            0
# 1355         4.0         4.0         2.0           0           98
# 809          1.0         3.0         0.0          40          156
# 446          4.0         4.0         2.0           0            0
# 927          4.0         4.0         2.0           0           43
# 975          4.0         4.0         2.0         153           50
# 1354         4.0         4.0         2.0           0          184
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  \
# 1257              0          0            0       0.0        0       7
# 683               0          0            0       0.0        0       7
# 1012            112          0           53       0.0        0       8
# 1018              0          0            0       0.0        0       5
# 1355              0          0            0       0.0        0       9
# 809               0          0            0       0.0        0      11
# 446               0          0            0       0.0        0       6
# 927               0          0            0       0.0        0       4
# 975               0          0            0       0.0        0       4
# 1354              0          0            0       0.0        0       6
#
#       YrSold  SaleType  SaleCondition  SalePrice
# 1257     3.0       8.0            4.0      99900
# 683      1.0       8.0            4.0     285000
# 1012     1.0       8.0            4.0     165000
# 1018     1.0       8.0            4.0     160000
# 1355     0.0       8.0            4.0     170000
# 809      3.0       8.0            4.0     106000
# 446      4.0       8.0            4.0     190000
# 927      2.0       8.0            4.0     176000
# 975      0.0       8.0            4.0     165000
# 1354     2.0       8.0            4.0     235000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   float64
#  5   LotShape       1460 non-null   float64
#  6   LandContour    1460 non-null   float64
#  7   Utilities      1460 non-null   float64
#  8   LotConfig      1460 non-null   float64
#  9   LandSlope      1460 non-null   float64
#  10  Neighborhood   1460 non-null   float64
#  11  Condition1     1460 non-null   float64
#  12  Condition2     1460 non-null   float64
#  13  BldgType       1460 non-null   float64
#  14  HouseStyle     1460 non-null   float64
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   float64
#  17  YearBuilt      1460 non-null   int64
#  18  YearRemodAdd   1460 non-null   int64
#  19  RoofStyle      1460 non-null   float64
#  20  RoofMatl       1460 non-null   float64
#  21  Exterior1st    1460 non-null   float64
#  22  Exterior2nd    1460 non-null   float64
#  23  MasVnrArea     1460 non-null   float64
#  24  ExterQual      1460 non-null   float64
#  25  ExterCond      1460 non-null   float64
#  26  Foundation     1460 non-null   float64
#  27  BsmtQual       1460 non-null   float64
#  28  BsmtCond       1460 non-null   float64
#  29  BsmtExposure   1460 non-null   float64
#  30  BsmtFinType1   1460 non-null   float64
#  31  BsmtFinSF1     1460 non-null   int64
#  32  BsmtFinType2   1460 non-null   float64
#  33  BsmtFinSF2     1460 non-null   int64
#  34  BsmtUnfSF      1460 non-null   int64
#  35  TotalBsmtSF    1460 non-null   int64
#  36  Heating        1460 non-null   float64
#  37  HeatingQC      1460 non-null   float64
#  38  CentralAir     1460 non-null   float64
#  39  Electrical     1460 non-null   float64
#  40  1stFlrSF       1460 non-null   int64
#  41  2ndFlrSF       1460 non-null   int64
#  42  LowQualFinSF   1460 non-null   int64
#  43  GrLivArea      1460 non-null   int64
#  44  BsmtFullBath   1460 non-null   float64
#  45  BsmtHalfBath   1460 non-null   float64
#  46  FullBath       1460 non-null   float64
#  47  HalfBath       1460 non-null   float64
#  48  BedroomAbvGr   1460 non-null   float64
#  49  KitchenAbvGr   1460 non-null   float64
#  50  KitchenQual    1460 non-null   float64
#  51  TotRmsAbvGrd   1460 non-null   int64
#  52  Functional     1460 non-null   float64
#  53  Fireplaces     1460 non-null   float64
#  54  GarageType     1460 non-null   float64
#  55  GarageYrBlt    1460 non-null   float64
#  56  GarageFinish   1460 non-null   float64
#  57  GarageCars     1460 non-null   float64
#  58  GarageArea     1460 non-null   int64
#  59  GarageQual     1460 non-null   float64
#  60  GarageCond     1460 non-null   float64
#  61  PavedDrive     1460 non-null   float64
#  62  WoodDeckSF     1460 non-null   int64
#  63  OpenPorchSF    1460 non-null   int64
#  64  EnclosedPorch  1460 non-null   int64
#  65  3SsnPorch      1460 non-null   int64
#  66  ScreenPorch    1460 non-null   int64
#  67  PoolArea       1460 non-null   float64
#  68  MiscVal        1460 non-null   int64
#  69  MoSold         1460 non-null   int64
#  70  YrSold         1460 non-null   float64
#  71  SaleType       1460 non-null   float64
#  72  SaleCondition  1460 non-null   float64
#  73  SalePrice      1460 non-null   int64
# dtypes: float64(50), int64(24)
# memory usage: 844.2 KB

# %%
from scipy.stats import f_oneway
for variable in CategoricalVariables:
    data.boxplot(column=TargetVariable, by=variable)
    AnovaTest = f_oneway(data[variable], data[TargetVariable])
    if (AnovaTest[1] < 0.05):
        print(variable, "is correlated with target variable\nP Value:", AnovaTest[1])
    else:
        print(variable, "is NOT correlated with target variable\nP Value:", AnovaTest[1])
# Out:
# MSZoning is correlated with target variable
# P Value: 0.0
# Street is correlated with target variable
# P Value: 0.0
# LotShape is correlated with target variable
# P Value: 0.0
# LandContour is correlated with target variable
# P Value: 0.0
# Utilities is correlated with target variable
# P Value: 0.0
# LotConfig is correlated with target variable
# P Value: 0.0
# LandSlope is correlated with target variable
# P Value: 0.0
# Neighborhood is correlated with target variable
# P Value: 0.0
# Condition1 is correlated with target variable
# P Value: 0.0
# Condition2 is correlated with target variable
# P Value: 0.0
# BldgType is correlated with target variable
# P Value: 0.0
# HouseStyle is correlated with target variable
# P Value: 0.0
# OverallCond is correlated with target variable
# P Value: 0.0
# RoofStyle is correlated with target variable
# P Value: 0.0
# RoofMatl is correlated with target variable
# P Value: 0.0
# Exterior1st is correlated with target variable
# P Value: 0.0
# Exterior2nd is correlated with target variable
# P Value: 0.0
# ExterQual is correlated with target variable
# P Value: 0.0
# ExterCond is correlated with target variable
# P Value: 0.0
# Foundation is correlated with target variable
# P Value: 0.0
# BsmtQual is correlated with target variable
# P Value: 0.0
# BsmtCond is correlated with target variable
# P Value: 0.0
# BsmtExposure is correlated with target variable
# P Value: 0.0
# BsmtFinType1 is correlated with target variable
# P Value: 0.0
# BsmtFinType2 is correlated with target variable
# P Value: 0.0
# Heating is correlated with target variable
# P Value: 0.0
# HeatingQC is correlated with target variable
# P Value: 0.0
# CentralAir is correlated with target variable
# P Value: 0.0
# Electrical is correlated with target variable
# P Value: 0.0
# BsmtFullBath is correlated with target variable
# P Value: 0.0
# BsmtHalfBath is correlated with target variable
# P Value: 0.0
# FullBath is correlated with target variable
# P Value: 0.0
# HalfBath is correlated with target variable
# P Value: 0.0
# BedroomAbvGr is correlated with target variable
# P Value: 0.0
# KitchenAbvGr is correlated with target variable
# P Value: 0.0
# KitchenQual is correlated with target variable
# P Value: 0.0
# Functional is correlated with target variable
# P Value: 0.0
# Fireplaces is correlated with target variable
# P Value: 0.0
# GarageType is correlated with target variable
# P Value: 0.0
# GarageFinish is correlated with target variable
# P Value: 0.0
# GarageCars is correlated with target variable
# P Value: 0.0
# GarageQual is correlated with target variable
# P Value: 0.0
# GarageCond is correlated with target variable
# P Value: 0.0
# PavedDrive is correlated with target variable
# P Value: 0.0
# PoolArea is correlated with target variable
# P Value: 0.0
# YrSold is correlated with target variable
# P Value: 0.0
# SaleType is correlated with target variable
# P Value: 0.0
# SaleCondition is correlated with target variable
# P Value: 0.0

# %%
import matplotlib.pyplot as pyplot
import numpy
CorrelationData = data[ContinousVariables]
CorrelationData['SalePrice'] = data['SalePrice']
CorrelationMatrix = CorrelationData.corr()
CorrelationMatrix

pyplot.figure(figsize=(15,10))

mask = numpy.triu(numpy.ones_like(CorrelationMatrix, dtype=bool))

sns.heatmap(CorrelationMatrix,
            cmap='RdBu_r',
            annot=True,
            fmt='.2f',
            vmin=-1, vmax=1)

pyplot.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree

# %%
PredictorVariables.append('OverallQual')
PredictorVariables.append('YearBuilt')
PredictorVariables.append('YearRemodAdd')
PredictorVariables.append('TotalBsmtSF')
PredictorVariables.append('1stFlrSF')
PredictorVariables.append('GrLivArea')
PredictorVariables.append('TotRmsAbvGrd')
PredictorVariables.append('GarageArea')

# %%
for variable in CategoricalVariables:
    PredictorVariables.append(variable)

# %%
missing_values = data[PredictorVariables].isnull().sum()
missing_values
# Out:
# OverallQual      0
# YearBuilt        0
# YearRemodAdd     0
# TotalBsmtSF      0
# 1stFlrSF         0
# GrLivArea        0
# TotRmsAbvGrd     0
# GarageArea       0
# MSZoning         0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallCond      0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# Functional       0
# Fireplaces       0
# GarageType       0
# GarageFinish     0
# GarageCars       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# PoolArea         0
# YrSold           0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
X_train = data[PredictorVariables]
Y_train = data[TargetVariable]
X_test = testdata[PredictorVariables]

RandomForest = RandomForestRegressor(criterion='squared_error', max_depth=8, n_estimators=100)
RandomForest.fit(X_train, Y_train)

Y_pred = RandomForest.predict(X_test)

fig, axs = pyplot.subplots(nrows = 1, ncols = 10, figsize = (10,2), dpi=900)

for i in range(0, 10):
    plot_tree(RandomForest.estimators_[i], filled = True, ax = axs[i])
    axs[i].set_title('Tree ' + str(i + 1) + ' of 100', fontsize = 5)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# Compute Mean Squared Error (MSE)
mse = mean_squared_error(Y_train, RandomForest.predict(X_train))
print("Mean Squared Error (MSE):", mse)

# Compute Mean Absolute Error (MAE)
mae = mean_absolute_error(Y_train, RandomForest.predict(X_train))
print("Mean Absolute Error (MAE):", mae)

# Compute R-squared (R²)
r2 = r2_score(Y_train, RandomForest.predict(X_train))
print("R-squared (R²):", r2)
# Out:
# Mean Squared Error (MSE): 233820405.1096666
# Mean Absolute Error (MAE): 11004.499719597376
# R-squared (R²): 0.9629255996224715

# %%
import matplotlib.pyplot as plt

# Scatter plot for actual vs. predicted values
plt.figure(figsize=(8, 6))
plt.scatter(Y_train, RandomForest.predict(X_train), alpha=0.5)
plt.xlabel("Actual SalePrice")
plt.ylabel("Predicted SalePrice")
plt.title("Actual vs. Predicted SalePrice (Training Data)")
plt.grid(True)
plt.show()
